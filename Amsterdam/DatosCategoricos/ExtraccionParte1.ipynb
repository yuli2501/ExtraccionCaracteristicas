# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
data = pd.read_csv('ValoresAtipicosMilan.csv', index_col="id")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23705 entries, 6400 to 1247058921429251974
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  23705 non-null  object
#  1   name                                          23705 non-null  object
#  2   host_id                                       23705 non-null  int64
#  3   host_name                                     23705 non-null  object
#  4   host_since                                    23705 non-null  object
#  5   host_response_time                            23705 non-null  object
#  6   host_is_superhost                             23705 non-null  object
#  7   host_identity_verified                        23705 non-null  object
#  8   neighbourhood                                 23705 non-null  object
#  9   neighbourhood_cleansed                        23705 non-null  object
#  10  latitude                                      23705 non-null  float64
#  11  longitude                                     23705 non-null  float64
#  12  property_type                                 23705 non-null  object
#  13  room_type                                     23705 non-null  object
#  14  amenities                                     23705 non-null  object
#  15  calendar_last_scraped                         23705 non-null  object
#  16  has_availability                              23705 non-null  object
#  17  first_review                                  23705 non-null  object
#  18  last_review                                   23705 non-null  object
#  19  license                                       23705 non-null  object
#  20  instant_bookable                              23705 non-null  object
#  21  host_response_rate                            23705 non-null  float64
#  22  host_acceptance_rate                          23705 non-null  float64
#  23  host_listings_count                           23705 non-null  float64
#  24  host_total_listings_count                     23705 non-null  float64
#  25  accommodates                                  23705 non-null  float64
#  26  bathrooms                                     23705 non-null  float64
#  27  bedrooms                                      23705 non-null  float64
#  28  beds                                          23705 non-null  float64
#  29  price                                         23705 non-null  float64
#  30  minimum_nights                                23705 non-null  float64
#  31  maximum_nights                                23705 non-null  int64
#  32  minimum_nights_avg_ntm                        23705 non-null  float64
#  33  maximum_nights_avg_ntm                        23705 non-null  float64
#  34  availability_30                               23705 non-null  int64
#  35  availability_90                               23705 non-null  int64
#  36  availability_365                              23705 non-null  int64
#  37  number_of_reviews                             23705 non-null  float64
#  38  review_scores_rating                          23705 non-null  float64
#  39  review_scores_accuracy                        23705 non-null  float64
#  40  review_scores_cleanliness                     23705 non-null  float64
#  41  review_scores_checkin                         23705 non-null  float64
#  42  review_scores_communication                   23705 non-null  float64
#  43  review_scores_location                        23705 non-null  float64
#  44  review_scores_value                           23705 non-null  float64
#  45  calculated_host_listings_count                23705 non-null  float64
#  46  calculated_host_listings_count_entire_homes   23705 non-null  float64
#  47  calculated_host_listings_count_private_rooms  23705 non-null  float64
#  48  calculated_host_listings_count_shared_rooms   23705 non-null  float64
# dtypes: float64(26), int64(5), object(18)
# memory usage: 9.0+ MB

# %%
data.head()
# Out:
#       last_scraped                                            name  host_id  \
# id
# 6400    2024-09-17                                The Studio Milan    13822
# 23986   2024-09-17                 " Characteristic Milanese flat"    95941
# 40470   2024-09-17             Giacinto Cosy & clean flat near MM1   174203
# 46536   2024-09-17                     Nico & Cinzia's Pink Suite!   138683
# 59226   2024-09-18  Near Piazza Gae Aulenti silent e reserved flat   244087
#
#          host_name  host_since host_response_time host_is_superhost  \
# id
# 6400     Francesca  2009-04-17            Unknown                 f
# 23986       Jeremy  2010-03-19     within an hour                 f
# 40470     Giacinto  2010-07-20     within an hour                 f
# 46536  Nico&Cinzia  2010-06-05            Unknown                 f
# 59226    Francesca  2010-09-24            Unknown                 f
#
#       host_identity_verified           neighbourhood neighbourhood_cleansed  \
# id
# 6400                       f  Milan, Lombardy, Italy                TIBALDI
# 23986                      t                   Milan                NAVIGLI
# 40470                      t                   Milan            VIALE MONZA
# 46536                      t  Milan, Lombardy, Italy            VIALE MONZA
# 59226                      t  Milan, Lombardy, Italy               CENTRALE
#
#        ...  review_scores_accuracy  review_scores_cleanliness  \
# id     ...
# 6400   ...                    5.00                       5.00
# 23986  ...                    4.67                       4.22
# 40470  ...                    4.71                       4.83
# 46536  ...                    4.61                       4.64
# 59226  ...                    4.33                       3.89
#
#       review_scores_checkin review_scores_communication  \
# id
# 6400                   5.00                        5.00
# 23986                  4.59                        4.74
# 40470                  4.98                        4.88
# 46536                  4.83                        4.92
# 59226                  4.89                        4.89
#
#       review_scores_location review_scores_value  \
# id
# 6400                    4.56                4.67
# 23986                   4.70                4.48
# 40470                   4.44                4.51
# 46536                   4.33                4.58
# 59226                   4.44                4.44
#
#       calculated_host_listings_count  \
# id
# 6400                             1.0
# 23986                            1.0
# 40470                            2.0
# 46536                            1.0
# 59226                            1.0
#
#       calculated_host_listings_count_entire_homes  \
# id
# 6400                                          0.0
# 23986                                         1.0
# 40470                                         2.0
# 46536                                         1.0
# 59226                                         1.0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 6400                                           1.0
# 23986                                          0.0
# 40470                                          0.0
# 46536                                          0.0
# 59226                                          0.0
#
#       calculated_host_listings_count_shared_rooms
# id
# 6400                                          0.0
# 23986                                         0.0
# 40470                                         0.0
# 46536                                         0.0
# 59226                                         0.0
#
# [5 rows x 49 columns]

# %%
freq_tbl(data)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   2024-09-17      21359    0.901034         0.901034
# 1   2024-09-18       2346    0.098966         1.000000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0                                    Appartamento Milano         10
# 1       Prestige Boutique Aparthotel - Piazza Duomo View          9
# 2                          Appartamento vicino al centro          7
# 3                                Cozy Apartment in Milan          6
# 4                        Appartamento incantevole Milano          6
# ...                                                  ...        ...
# 23244      Co99 Art Building - Comfort Room ( disabili )          1
# 23245             @Corso Garibaldi con vista sulla città          1
# 23246                            PrimoPiano - Pavia Flat          1
# 23247    Incantevole stanza monolocale con bagno privato          1
# 23248  Sonder Manzoni | One-Bedroom Apartment w/ Balcony          1
#
#        percentage  cumulative_perc
# 0        0.000422         0.000422
# 1        0.000380         0.000802
# 2        0.000295         0.001097
# 3        0.000253         0.001350
# 4        0.000253         0.001603
# ...           ...              ...
# 23244    0.000042         0.999831
# 23245    0.000042         0.999873
# 23246    0.000042         0.999916
# 23247    0.000042         0.999958
# 23248    0.000042         1.000000
#
# [23249 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                 host_name  frequency  percentage  cumulative_perc
# 0                  Andrea        554    0.023371         0.023371
# 1              Italianway        518    0.021852         0.045223
# 2          Easylife House        372    0.015693         0.060915
# 3               Francesco        354    0.014934         0.075849
# 4                   Marco        349    0.014723         0.090572
# ...                   ...        ...         ...              ...
# 3025              Leandra          1    0.000042         0.999831
# 3026                 Wail          1    0.000042         0.999873
# 3027  Franco SanSiroHouse          1    0.000042         0.999916
# 3028                 Melo          1    0.000042         0.999958
# 3029     Francesca Simona          1    0.000042         1.000000
#
# [3030 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     2015-02-13        518    0.021852         0.021852
# 1     2013-09-24        346    0.014596         0.036448
# 2     2014-06-04        309    0.013035         0.049483
# 3     2012-05-30        152    0.006412         0.055895
# 4     2016-01-10        149    0.006286         0.062181
# ...          ...        ...         ...              ...
# 4193  2022-09-03          1    0.000042         0.999831
# 4194  2022-08-20          1    0.000042         0.999873
# 4195  2018-05-30          1    0.000042         0.999916
# 4196  2016-09-21          1    0.000042         0.999958
# 4197  2024-09-15          1    0.000042         1.000000
#
# [4198 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      15488    0.653364         0.653364
# 1             Unknown       3854    0.162582         0.815946
# 2  within a few hours       2214    0.093398         0.909344
# 3        within a day       1418    0.059819         0.969163
# 4  a few days or more        731    0.030837         1.000000
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      17131    0.722675         0.722675
# 1                 t       6574    0.277325         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22316    0.941405         0.941405
# 1                      f       1389    0.058595         1.000000
#
# ----------------------------------------------------------------
#
#                                         neighbourhood  frequency  percentage  \
# 0                            Milano, Lombardia, Italy      11621    0.490234
# 1                                               Milan      11377    0.479941
# 2                              Milan, Lombardy, Italy        534    0.022527
# 3                                       Milano, Italy         35    0.001476
# 4                                   Milano, MI, Italy         33    0.001392
# 5                                   Milano, Lo, Italy         11    0.000464
# 6                                        Milan, Italy         10    0.000422
# 7                                    Milan, MI, Italy         10    0.000422
# 8                             Milan, Lombardia, Italy          9    0.000380
# 9                                   Milano, Mi, Italy          7    0.000295
# 10                               Milan, Milano, Italy          4    0.000169
# 11               Sesto San Giovanni, Lombardia, Italy          3    0.000127
# 12                            Milano, Lombardy, Italy          3    0.000127
# 13                   Milano, Milano, Lombardia, Italy          3    0.000127
# 14                          Milano , Lombardia, Italy          3    0.000127
# 15                              Milano, Italia, Italy          3    0.000127
# 16                 Milano - Navigli, Lombardia, Italy          2    0.000084
# 17                                   Milan, Mi, Italy          2    0.000084
# 18       Milano, Città Metropolitana di Milano, Italy          2    0.000084
# 19                              Milano, milano, Italy          1    0.000042
# 20                                   Milan, Lo, Italy          1    0.000042
# 21                Casoretto, Milano, Lombardia, Italy          1    0.000042
# 22              Milan, Italy, Lombardia, Italy, Italy          1    0.000042
# 23                  Milano,  Italia, Lombardia, Italy          1    0.000042
# 24              Chiaravalle, Milano, Lombardia, Italy          1    0.000042
# 25                        Noverasco, Lombardia, Italy          1    0.000042
# 26           Milano, Italia, Milano, Lombardia, Italy          1    0.000042
# 27     Milano, Italy, Lombardia, Milano ( MI ), Italy          1    0.000042
# 28  Milano, San Cristoforo sul Naviglio, Lombardia...          1    0.000042
# 29                           Figino, Lombardia, Italy          1    0.000042
# 30                          Cormano, Lombardia, Italy          1    0.000042
# 31                           Bresso, Lombardia, Italy          1    0.000042
# 32                         Ambrogio, Lombardia, Italy          1    0.000042
# 33                  Milano, Milano / Lombardia, Italy          1    0.000042
# 34                     Milano, Lombardia/Italy, Italy          1    0.000042
# 35                    milano (isola), Lombardy, Italy          1    0.000042
# 36                             Milano , Milano, Italy          1    0.000042
# 37           Milano, Italia, Milano, Lombardia, Italy          1    0.000042
# 38                  Milano, Lombardia - Italia, Italy          1    0.000042
# 39                                              Italy          1    0.000042
# 40                    Milano centro, Lombardia, Italy          1    0.000042
# 41                             Milano , Italia, Italy          1    0.000042
# 42                                 Milano , Mi, Italy          1    0.000042
# 43                 Settimo Milanese, Lombardia, Italy          1    0.000042
# 44                        Vimodrone, Lombardia, Italy          1    0.000042
# 45                    Settimo Milanese, milano, Italy          1    0.000042
# 46                   Zona 9, Milano, Lombardia, Italy          1    0.000042
# 47          Milano (Porta Venezia) , Lombardia, Italy          1    0.000042
# 48  Via Alfonso Capecelatro, Milan, Metropolitan C...          1    0.000042
# 49                  Milano \nMilano, Lombardia, Italy          1    0.000042
# 50                     porta Genova, Lombardia, Italy          1    0.000042
# 51              San Donato Milanese, Lombardia, Italy          1    0.000042
#
#     cumulative_perc
# 0          0.490234
# 1          0.970175
# 2          0.992702
# 3          0.994178
# 4          0.995571
# 5          0.996035
# 6          0.996456
# 7          0.996878
# 8          0.997258
# 9          0.997553
# 10         0.997722
# 11         0.997849
# 12         0.997975
# 13         0.998102
# 14         0.998228
# 15         0.998355
# 16         0.998439
# 17         0.998524
# 18         0.998608
# 19         0.998650
# 20         0.998692
# 21         0.998734
# 22         0.998777
# 23         0.998819
# 24         0.998861
# 25         0.998903
# 26         0.998945
# 27         0.998988
# 28         0.999030
# 29         0.999072
# 30         0.999114
# 31         0.999156
# 32         0.999198
# 33         0.999241
# 34         0.999283
# 35         0.999325
# 36         0.999367
# 37         0.999409
# 38         0.999452
# 39         0.999494
# 40         0.999536
# 41         0.999578
# 42         0.999620
# 43         0.999663
# 44         0.999705
# 45         0.999747
# 46         0.999789
# 47         0.999831
# 48         0.999873
# 49         0.999916
# 50         0.999958
# 51         1.000000
#
# ----------------------------------------------------------------
#
#     neighbourhood_cleansed  frequency  percentage  cumulative_perc
# 0   BUENOS AIRES - VENEZIA       1852    0.078127         0.078127
# 1                    DUOMO       1473    0.062139         0.140266
# 2                    SARPI       1012    0.042691         0.182957
# 3                    BRERA        989    0.041721         0.224678
# 4                   LORETO        964    0.040667         0.265345
# ..                     ...        ...         ...              ...
# 83              PARCO NORD          3    0.000127         0.999663
# 84              STEPHENSON          3    0.000127         0.999789
# 85      PARCO AGRICOLO SUD          2    0.000084         0.999873
# 86    RONCHETTO DELLE RANE          2    0.000084         0.999958
# 87  CASCINA TRIULZA - EXPO          1    0.000042         1.000000
#
# [88 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit      14131    0.596119         0.596119
# 1                         Entire condo       4788    0.201983         0.798102
# 2          Private room in rental unit       1679    0.070829         0.868931
# 3                Private room in condo        727    0.030669         0.899599
# 4                          Entire loft        586    0.024721         0.924320
# 5                          Entire home        405    0.017085         0.941405
# 6            Entire serviced apartment        253    0.010673         0.952078
# 7                 Entire vacation home        192    0.008100         0.960177
# 8    Private room in bed and breakfast        172    0.007256         0.967433
# 9                 Private room in home        124    0.005231         0.972664
# 10          Shared room in rental unit        105    0.004429         0.977093
# 11                       Room in hotel         77    0.003248         0.980342
# 12                Private room in loft         60    0.002531         0.982873
# 13              Room in boutique hotel         44    0.001856         0.984729
# 14               Shared room in hostel         32    0.001350         0.986079
# 15       Private room in vacation home         24    0.001012         0.987091
# 16              Private room in hostel         24    0.001012         0.988104
# 17                           Tiny home         23    0.000970         0.989074
# 18          Private room in guesthouse         22    0.000928         0.990002
# 19                  Entire guest suite         21    0.000886         0.990888
# 20               Private room in villa         20    0.000844         0.991732
# 21                Shared room in condo         17    0.000717         0.992449
# 22                        Entire place         17    0.000717         0.993166
# 23                    Entire townhouse         17    0.000717         0.993883
# 24  Private room in serviced apartment         16    0.000675         0.994558
# 25                        Entire villa         16    0.000675         0.995233
# 26         Private room in guest suite         14    0.000591         0.995824
# 27           Private room in townhouse         13    0.000548         0.996372
# 28    Shared room in bed and breakfast          9    0.000380         0.996752
# 29           Room in bed and breakfast          9    0.000380         0.997131
# 30                        Private room          8    0.000337         0.997469
# 31     Private room in casa particular          8    0.000337         0.997806
# 32                  Room in aparthotel          8    0.000337         0.998144
# 33                     Casa particular          7    0.000295         0.998439
# 34                Shared room in hotel          6    0.000253         0.998692
# 35                 Shared room in home          4    0.000169         0.998861
# 36                           Camper/RV          4    0.000169         0.999030
# 37                 Shared room in loft          3    0.000127         0.999156
# 38           Private room in tiny home          3    0.000127         0.999283
# 39           Private room in farm stay          3    0.000127         0.999409
# 40                      Room in hostel          3    0.000127         0.999536
# 41                   Entire guesthouse          1    0.000042         0.999578
# 42          Room in serviced apartment          1    0.000042         0.999620
# 43        Private room in nature lodge          1    0.000042         0.999663
# 44                     Entire home/apt          1    0.000042         0.999705
# 45                       Entire chalet          1    0.000042         0.999747
# 46                                Boat          1    0.000042         0.999789
# 47                Private room in cave          1    0.000042         0.999831
# 48               Private room in minsu          1    0.000042         0.999873
# 49           Shared room in guesthouse          1    0.000042         0.999916
# 50           Private room in camper/rv          1    0.000042         0.999958
# 51                  Shipping container          1    0.000042         1.000000
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      20469    0.863489         0.863489
# 1     Private room       3040    0.128243         0.991732
# 2      Shared room        177    0.007467         0.999198
# 3       Hotel room         19    0.000802         1.000000
#
# ----------------------------------------------------------------
#
#                                                amenities  frequency  \
# 0      ["Wifi", "Kitchen", "Air conditioning", "Washe...        131
# 1      ["Wifi", "Kitchen", "Dedicated workspace", "Ai...         64
# 2                    ["Wifi", "Washer", "TV", "Kitchen"]         60
# 3                                                     []         45
# 4      ["Wifi", "Lock on bedroom door", "Kitchen", "W...         34
# ...                                                  ...        ...
# 22157  ["Hot water", "AC - split type ductless system...          1
# 22158  ["Hot water", "AC - split type ductless system...          1
# 22159  ["Hot water", "Mosquito net", "Books and readi...          1
# 22160  ["Wifi", "Hangers", "Elevator", "Host greets y...          1
# 22161  ["First aid kit", "Hangers", "Wifi", "Elevator...          1
#
#        percentage  cumulative_perc
# 0        0.005526         0.005526
# 1        0.002700         0.008226
# 2        0.002531         0.010757
# 3        0.001898         0.012656
# 4        0.001434         0.014090
# ...           ...              ...
# 22157    0.000042         0.999831
# 22158    0.000042         0.999873
# 22159    0.000042         0.999916
# 22160    0.000042         0.999958
# 22161    0.000042         1.000000
#
# [22162 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   calendar_last_scraped  frequency  percentage  cumulative_perc
# 0            2024-09-17      21361    0.901118         0.901118
# 1            2024-09-18       2344    0.098882         1.000000
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      23705         1.0              1.0
#
# ----------------------------------------------------------------
#
#      first_review  frequency  percentage  cumulative_perc
# 0      No reviews       3978    0.167813         0.167813
# 1      2024-04-19        179    0.007551         0.175364
# 2      2024-04-18        178    0.007509         0.182873
# 3      2024-04-21        166    0.007003         0.189876
# 4      2024-04-20        129    0.005442         0.195317
# ...           ...        ...         ...              ...
# 3097   2021-05-12          1    0.000042         0.999831
# 3098   2016-06-24          1    0.000042         0.999873
# 3099   2016-02-27          1    0.000042         0.999916
# 3100   2016-01-24          1    0.000042         0.999958
# 3101   2010-04-19          1    0.000042         1.000000
#
# [3102 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#      last_review  frequency  percentage  cumulative_perc
# 0     No reviews       3978    0.167813         0.167813
# 1     2024-09-02       1035    0.043662         0.211474
# 2     2024-09-15        697    0.029403         0.240877
# 3     2024-09-01        588    0.024805         0.265682
# 4     2024-09-16        539    0.022738         0.288420
# ...          ...        ...         ...              ...
# 1408  2021-06-10          1    0.000042         0.999831
# 1409  2017-09-12          1    0.000042         0.999873
# 1410  2017-07-20          1    0.000042         0.999916
# 1411  2020-12-22          1    0.000042         0.999958
# 1412  2023-12-21          1    0.000042         1.000000
#
# [1413 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                                 license  frequency  \
# 0                                               Unknown      13536
# 1                                      015146-CIM-00186        108
# 2                                      015146-CIM-00587         45
# 3                                      015146-CIM-00172         23
# 4                                                Exempt         23
# ...                                                 ...        ...
# 9171                                   015146-LNI-00773          1
# 9172  Codice CIR: 015146-CNI-04844   Codice struttur...          1
# 9173                                 IT015146C2JDXRG99S          1
# 9174                                 IT015146B4DARJA472          1
# 9175                                   IT015146CIN06130          1
#
#       percentage  cumulative_perc
# 0       0.571019         0.571019
# 1       0.004556         0.575575
# 2       0.001898         0.577473
# 3       0.000970         0.578443
# 4       0.000970         0.579414
# ...          ...              ...
# 9171    0.000042         0.999831
# 9172    0.000042         0.999873
# 9173    0.000042         0.999916
# 9174    0.000042         0.999958
# 9175    0.000042         1.000000
#
# [9176 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      12680    0.534908         0.534908
# 1                t      11025    0.465092         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# **host_response_time**

# %%
#Obtengo un analisis univariado de una variable categorica en especifico
table1 = freq_tbl(data['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      15488    0.653364         0.653364
# 1             Unknown       3854    0.162582         0.815946
# 2  within a few hours       2214    0.093398         0.909344
# 3        within a day       1418    0.059819         0.969163
# 4  a few days or more        731    0.030837         1.000000

# %%
#Debemos quedarnos solo con la información significativa 
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#    host_response_time  frequency
# 0      within an hour      15488
# 1             Unknown       3854
# 2  within a few hours       2214
# 3        within a day       1418
# 4  a few days or more        731

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = table2.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour          15488
# Unknown                  3854
# within a few hours       2214
# within a day             1418
# a few days or more        731

# %%
Filtro_index['frequency'].plot(kind='pie', figsize=(10,5), shadow=False, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **host_is_superhost**

# %%
table1 = freq_tbl(data['host_is_superhost'])
table1
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      17131    0.722675         0.722675
# 1                 t       6574    0.277325         1.000000

# %%
#Debemos quedarnos solo con la información significativa 
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#   host_is_superhost  frequency
# 0                 f      17131
# 1                 t       6574

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = table2.set_index('host_is_superhost')
Filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                      17131
# t                       6574

# %%
#Realizamos grafica de barras del dataframe filtrado
Filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='pink')
plt.title('Superhost')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **host_identity_verified**

# %%
table1 = freq_tbl(data['host_identity_verified'])
table1
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      22316    0.941405         0.941405
# 1                      f       1389    0.058595         1.000000

# %%
#Debemos quedarnos solo con la información significativa 
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#   host_identity_verified  frequency
# 0                      t      22316
# 1                      f       1389

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = table2.set_index('host_identity_verified')
Filtro_index
# Out:
#                         frequency
# host_identity_verified
# t                           22316
# f                            1389

# %%
#Realizamos grafica de barras del dataframe filtrado
Filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='blue')
plt.title('Identidad verificada')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **property_type**

# %%
table1 = freq_tbl(data['property_type'])
table1
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit      14131    0.596119         0.596119
# 1                         Entire condo       4788    0.201983         0.798102
# 2          Private room in rental unit       1679    0.070829         0.868931
# 3                Private room in condo        727    0.030669         0.899599
# 4                          Entire loft        586    0.024721         0.924320
# 5                          Entire home        405    0.017085         0.941405
# 6            Entire serviced apartment        253    0.010673         0.952078
# 7                 Entire vacation home        192    0.008100         0.960177
# 8    Private room in bed and breakfast        172    0.007256         0.967433
# 9                 Private room in home        124    0.005231         0.972664
# 10          Shared room in rental unit        105    0.004429         0.977093
# 11                       Room in hotel         77    0.003248         0.980342
# 12                Private room in loft         60    0.002531         0.982873
# 13              Room in boutique hotel         44    0.001856         0.984729
# 14               Shared room in hostel         32    0.001350         0.986079
# 15       Private room in vacation home         24    0.001012         0.987091
# 16              Private room in hostel         24    0.001012         0.988104
# 17                           Tiny home         23    0.000970         0.989074
# 18          Private room in guesthouse         22    0.000928         0.990002
# 19                  Entire guest suite         21    0.000886         0.990888
# 20               Private room in villa         20    0.000844         0.991732
# 21                Shared room in condo         17    0.000717         0.992449
# 22                        Entire place         17    0.000717         0.993166
# 23                    Entire townhouse         17    0.000717         0.993883
# 24  Private room in serviced apartment         16    0.000675         0.994558
# 25                        Entire villa         16    0.000675         0.995233
# 26         Private room in guest suite         14    0.000591         0.995824
# 27           Private room in townhouse         13    0.000548         0.996372
# 28    Shared room in bed and breakfast          9    0.000380         0.996752
# 29           Room in bed and breakfast          9    0.000380         0.997131
# 30                        Private room          8    0.000337         0.997469
# 31     Private room in casa particular          8    0.000337         0.997806
# 32                  Room in aparthotel          8    0.000337         0.998144
# 33                     Casa particular          7    0.000295         0.998439
# 34                Shared room in hotel          6    0.000253         0.998692
# 35                 Shared room in home          4    0.000169         0.998861
# 36                           Camper/RV          4    0.000169         0.999030
# 37                 Shared room in loft          3    0.000127         0.999156
# 38           Private room in tiny home          3    0.000127         0.999283
# 39           Private room in farm stay          3    0.000127         0.999409
# 40                      Room in hostel          3    0.000127         0.999536
# 41                   Entire guesthouse          1    0.000042         0.999578
# 42          Room in serviced apartment          1    0.000042         0.999620
# 43        Private room in nature lodge          1    0.000042         0.999663
# 44                     Entire home/apt          1    0.000042         0.999705
# 45                       Entire chalet          1    0.000042         0.999747
# 46                                Boat          1    0.000042         0.999789
# 47                Private room in cave          1    0.000042         0.999831
# 48               Private room in minsu          1    0.000042         0.999873
# 49           Shared room in guesthouse          1    0.000042         0.999916
# 50           Private room in camper/rv          1    0.000042         0.999958
# 51                  Shipping container          1    0.000042         1.000000

# %%
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#                          property_type  frequency
# 0                   Entire rental unit      14131
# 1                         Entire condo       4788
# 2          Private room in rental unit       1679
# 3                Private room in condo        727
# 4                          Entire loft        586
# 5                          Entire home        405
# 6            Entire serviced apartment        253
# 7                 Entire vacation home        192
# 8    Private room in bed and breakfast        172
# 9                 Private room in home        124
# 10          Shared room in rental unit        105
# 11                       Room in hotel         77
# 12                Private room in loft         60
# 13              Room in boutique hotel         44
# 14               Shared room in hostel         32
# 15       Private room in vacation home         24
# 16              Private room in hostel         24
# 17                           Tiny home         23
# 18          Private room in guesthouse         22
# 19                  Entire guest suite         21
# 20               Private room in villa         20
# 21                Shared room in condo         17
# 22                        Entire place         17
# 23                    Entire townhouse         17
# 24  Private room in serviced apartment         16
# 25                        Entire villa         16
# 26         Private room in guest suite         14
# 27           Private room in townhouse         13
# 28    Shared room in bed and breakfast          9
# 29           Room in bed and breakfast          9
# 30                        Private room          8
# 31     Private room in casa particular          8
# 32                  Room in aparthotel          8
# 33                     Casa particular          7
# 34                Shared room in hotel          6
# 35                 Shared room in home          4
# 36                           Camper/RV          4
# 37                 Shared room in loft          3
# 38           Private room in tiny home          3
# 39           Private room in farm stay          3
# 40                      Room in hostel          3
# 41                   Entire guesthouse          1
# 42          Room in serviced apartment          1
# 43        Private room in nature lodge          1
# 44                     Entire home/apt          1
# 45                       Entire chalet          1
# 46                                Boat          1
# 47                Private room in cave          1
# 48               Private room in minsu          1
# 49           Shared room in guesthouse          1
# 50           Private room in camper/rv          1
# 51                  Shipping container          1

# %%
#Obtengo un filtro de los valores mas reelevantes de la variable categorica seleccionada 
Filtro = table2[table2['frequency'] > 20]
Filtro
# Out:
#                         property_type  frequency
# 0                  Entire rental unit      14131
# 1                        Entire condo       4788
# 2         Private room in rental unit       1679
# 3               Private room in condo        727
# 4                         Entire loft        586
# 5                         Entire home        405
# 6           Entire serviced apartment        253
# 7                Entire vacation home        192
# 8   Private room in bed and breakfast        172
# 9                Private room in home        124
# 10         Shared room in rental unit        105
# 11                      Room in hotel         77
# 12               Private room in loft         60
# 13             Room in boutique hotel         44
# 14              Shared room in hostel         32
# 15      Private room in vacation home         24
# 16             Private room in hostel         24
# 17                          Tiny home         23
# 18         Private room in guesthouse         22
# 19                 Entire guest suite         21

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = Filtro.set_index('property_type')
Filtro_index
# Out:
#                                    frequency
# property_type
# Entire rental unit                     14131
# Entire condo                            4788
# Private room in rental unit             1679
# Private room in condo                    727
# Entire loft                              586
# Entire home                              405
# Entire serviced apartment                253
# Entire vacation home                     192
# Private room in bed and breakfast        172
# Private room in home                     124
# Shared room in rental unit               105
# Room in hotel                             77
# Private room in loft                      60
# Room in boutique hotel                    44
# Shared room in hostel                     32
# Private room in vacation home             24
# Private room in hostel                    24
# Tiny home                                 23
# Private room in guesthouse                22
# Entire guest suite                        21

# %%
#Realizamos grafica de barras del dataframe filtrado
Filtro_index.plot(kind='bar', width=0.8, figsize=(12,6), color='green')
plt.title('Tipo de propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **room_type**

# %%
table1 = freq_tbl(data['room_type'])
table1
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      20469    0.863489         0.863489
# 1     Private room       3040    0.128243         0.991732
# 2      Shared room        177    0.007467         0.999198
# 3       Hotel room         19    0.000802         1.000000

# %%
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#          room_type  frequency
# 0  Entire home/apt      20469
# 1     Private room       3040
# 2      Shared room        177
# 3       Hotel room         19

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = table2.set_index('room_type')
Filtro_index
# Out:
#                  frequency
# room_type
# Entire home/apt      20469
# Private room          3040
# Shared room            177
# Hotel room              19

# %%
Filtro_index.plot(kind='bar', width=0.8, figsize=(10,5), color='orange')
plt.title('Tipo de habitacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **has_availability**

# %%
table1 = freq_tbl(data['has_availability'])
table1
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      23705         1.0              1.0

# %%
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis = 1)
table2
# Out:
#   has_availability  frequency
# 0                t      23705

# %%
#Ajusto el indice de mi dataframe 
Filtro_index = table2.set_index('has_availability')
Filtro_index
# Out:
#                   frequency
# has_availability
# t                     23705

# %%
#Realizamos grafico de pastel
Filtro_index['frequency'].plot(kind='pie', figsize=(10,5), shadow=False, autopct='%0.1f %%')
# Out:
# <Axes: ylabel='frequency'>
